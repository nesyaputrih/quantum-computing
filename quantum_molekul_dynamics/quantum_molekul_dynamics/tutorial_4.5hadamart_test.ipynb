# %% [markdown]
# ## **USING THE HADAMARD TEST FOR CALCULATING EXPECTATION VALUES**

# %%
# !pip install qiskit --quiet
# !pip install qiskit_ibm_runtime --quiet

import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as LA
from qiskit import *
from qiskit.quantum_info import Operator
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler, Batch

# %%
#hadamard test function
from qiskit import QuantumCircuit
def get_hadamard_test(num_q, init_circ, controlled_U,
                      control_repeats=1,
                      imag_expectation=False):
    anc = 1
    total_qubits = num_q + anc

    qc = QuantumCircuit(total_qubits, 1)

    # 1. initial state
    qc.compose(init_circ, qubits=range(1, num_q+1), inplace=True)

    # 2. Hadamard on ancilla
    qc.h(0)

    # 3. Imaginary part → S† gate
    if imag_expectation:
        qc.sdg(0)

    # 4. Controlled-U
    for _ in range(control_repeats):
        qc.append(controlled_U, list(range(controlled_U.num_qubits)))

    # 5. Hadamard again
    qc.h(0)

    # 6. Measurement
    qc.measure(0, 0)

    return qc   # <<< INI YANG SERING KELUPA

# %%
#hadamard test post processing
def get_spin_correlation(counts):
    qubit_to_spin_map = {
        '0' : 1,
        '1' : -1,
    }

    total_counts = 0
    value_list = []
    for k, v, in counts.items():
        value_list.append(qubit_to_spin_map[k] * v)
        total_counts += v
    average_spin = (sum(value_list))/total_counts
    return average_spin

# %%
from qiskit.quantum_info import SparsePauliOp
H = SparsePauliOp.from_list([
    ("ZZ", 1.0),
    ("XI", 0.5),
    ("IX", 0.5)
])

from qiskit.quantum_info import Operator
from scipy.linalg import expm
import numpy as np
from scipy.linalg import expm
from qiskit.circuit.library import UnitaryGate

def get_time_evolution_operator(H, t):
    H_mat = H.to_matrix()
    U = expm(-1j * H_mat * t)
    return UnitaryGate(U)

def create_init_circuit(num_q):
    qc = QuantumCircuit(num_q)
    qc.h(0)   # bikin superposition
    return qc
#creation of controled time evolution operator
#controlled_time_evo_op = time_evo_op.control()

# %%
#hadamart test execution
#statevector is no appropriate for this method
from qiskit_aer import AerSimulator
from qiskit import transpile
simulator = AerSimulator(method="statevector")

real_amp_list = []
imag_amp_list = []

time_range = np.linspace(0, 25, 100)
num_shots = 500000
num_q = 5
init_circ = QuantumCircuit(num_q)

for idx, time in enumerate(time_range):
    print(f'running dynamics step{idx}')
    U = get_time_evolution_operator(H, time)
    controlled_time_evo_op = U.control()

    #real component
    qc_had_real = get_hadamard_test(
        num_q, init_circ,
        controlled_time_evo_op,
        control_repeats=1,
        imag_expectation=False
    )
    qc_had_real = transpile(qc_had_real, simulator)
    job_real = simulator.run(qc_had_real, shots=num_shots)
    result_real = job_real.result()
    had_real_counts = result_real.get_counts()

    real_amplitude = get_spin_correlation(had_real_counts)
    real_amp_list.append(real_amplitude)

    #imag component
    qc_had_imag = get_hadamard_test(
        num_q, init_circ,
        controlled_time_evo_op,
        control_repeats=1,
        imag_expectation=True
    )
    qc_had_imag = transpile(qc_had_imag, simulator)
    job_imag = simulator.run(qc_had_imag, shots=num_shots)
    result_imag = job_imag.result()
    had_imag_counts = result_imag.get_counts()

    imag_amplitude = get_spin_correlation(had_imag_counts)
    imag_amp_list.append(imag_amplitude)

    print(f'Finished step {idx}, where '
          f'Re = {real_amplitude:.3f} '
          f'Im = {imag_amplitude:.3f}')
    
# convert to numpy
real_amp_array = np.array(real_amp_list)
imag_amp_array = np.array(imag_amp_list)

np_abs_correlation_with_hadamard_test = np.sqrt(
    real_amp_array**2 + imag_amp_array**2
)
np_abs_correlation_with_hadamard_test = np.clip(
    np_abs_correlation_with_hadamard_test, 0, 1
)

# plotting
n = len(time_range)
plt.plot(time_range,
         np_abs_correlation_with_hadamard_test[:n],
         '.', label='Hadamard Test')
plt.xlabel('Time')
plt.ylabel('Absolute Value of Survival Amplitude')
plt.legend()
plt.show()
# Out:
# running dynamics step0
# Finished step 0, where Re = 1.000 Im = -0.000
# running dynamics step1
# Finished step 1, where Re = 0.952 Im = -0.248
# running dynamics step2
# Finished step 2, where Re = 0.817 Im = -0.473
# running dynamics step3
# Finished step 3, where Re = 0.603 Im = -0.652
# running dynamics step4
# Finished step 4, where Re = 0.337 Im = -0.773
# running dynamics step5
# Finished step 5, where Re = 0.045 Im = -0.823
# running dynamics step6
# Finished step 6, where Re = -0.242 Im = -0.796
# running dynamics step7
# Finished step 7, where Re = -0.496 Im = -0.702
# running dynamics step8
# Finished step 8, where Re = -0.697 Im = -0.550
# running dynamics step9
# Finished step 9, where Re = -0.822 Im = -0.358
# running dynamics step10
# Finished step 10, where Re = -0.862 Im = -0.142
# running dynamics step11
# Finished step 11, where Re = -0.821 Im = 0.069
# running dynamics step12
# Finished step 12, where Re = -0.706 Im = 0.265
# running dynamics step13
# Finished step 13, where Re = -0.530 Im = 0.422
# running dynamics step14
# Finished step 14, where Re = -0.319 Im = 0.530
# running dynamics step15
# Finished step 15, where Re = -0.099 Im = 0.583
# running dynamics step16
# Finished step 16, where Re = 0.111 Im = 0.583
# running dynamics step17
# Finished step 17, where Re = 0.285 Im = 0.530
# running dynamics step18
# Finished step 18, where Re = 0.412 Im = 0.443
# running dynamics step19
# Finished step 19, where Re = 0.480 Im = 0.330
# running dynamics step20
# Finished step 20, where Re = 0.492 Im = 0.204
# running dynamics step21
# Finished step 21, where Re = 0.451 Im = 0.083
# running dynamics step22
# Finished step 22, where Re = 0.374 Im = -0.020
# running dynamics step23
# Finished step 23, where Re = 0.269 Im = -0.104
# running dynamics step24
# Finished step 24, where Re = 0.160 Im = -0.157
# running dynamics step25
# Finished step 25, where Re = 0.062 Im = -0.182
# running dynamics step26
# Finished step 26, where Re = -0.013 Im = -0.190
# running dynamics step27
# Finished step 27, where Re = -0.058 Im = -0.180
# running dynamics step28
# Finished step 28, where Re = -0.068 Im = -0.163
# running dynamics step29
# Finished step 29, where Re = -0.045 Im = -0.148
# running dynamics step30
# Finished step 30, where Re = -0.002 Im = -0.141
# running dynamics step31
# Finished step 31, where Re = 0.051 Im = -0.147
# running dynamics step32
# Finished step 32, where Re = 0.098 Im = -0.167
# running dynamics step33
# Finished step 33, where Re = 0.124 Im = -0.193
# running dynamics step34
# Finished step 34, where Re = 0.120 Im = -0.226
# running dynamics step35
# Finished step 35, where Re = 0.082 Im = -0.252
# running dynamics step36
# Finished step 36, where Re = 0.008 Im = -0.264
# running dynamics step37
# Finished step 37, where Re = -0.101 Im = -0.254
# running dynamics step38
# Finished step 38, where Re = -0.224 Im = -0.215
# running dynamics step39
# Finished step 39, where Re = -0.352 Im = -0.143
# running dynamics step40
# Finished step 40, where Re = -0.463 Im = -0.036
# running dynamics step41
# Finished step 41, where Re = -0.540 Im = 0.090
# running dynamics step42
# Finished step 42, where Re = -0.571 Im = 0.230
# running dynamics step43
# Finished step 43, where Re = -0.539 Im = 0.373
# running dynamics step44
# Finished step 44, where Re = -0.442 Im = 0.498
# running dynamics step45
# Finished step 45, where Re = -0.288 Im = 0.591
# running dynamics step46
# Finished step 46, where Re = -0.083 Im = 0.638
# running dynamics step47
# Finished step 47, where Re = 0.144 Im = 0.631
# running dynamics step48
# Finished step 48, where Re = 0.383 Im = 0.566
# running dynamics step49
# Finished step 49, where Re = 0.600 Im = 0.442
# running dynamics step50
# Finished step 50, where Re = 0.773 Im = 0.266
# running dynamics step51
# Finished step 51, where Re = 0.877 Im = 0.056
# running dynamics step52
# Finished step 52, where Re = 0.904 Im = -0.171
# running dynamics step53
# Finished step 53, where Re = 0.840 Im = -0.391
# running dynamics step54
# Finished step 54, where Re = 0.695 Im = -0.587
# running dynamics step55
# Finished step 55, where Re = 0.476 Im = -0.736
# running dynamics step56
# Finished step 56, where Re = 0.202 Im = -0.823
# running dynamics step57
# Finished step 57, where Re = -0.092 Im = -0.836
# running dynamics step58
# Finished step 58, where Re = -0.389 Im = -0.775
# running dynamics step59
# Finished step 59, where Re = -0.648 Im = -0.643
# running dynamics step60
# Finished step 60, where Re = -0.848 Im = -0.453
# running dynamics step61
# Finished step 61, where Re = -0.967 Im = -0.222
# running dynamics step62
# Finished step 62, where Re = -0.994 Im = 0.027
# running dynamics step63
# Finished step 63, where Re = -0.927 Im = 0.270
# running dynamics step64
# Finished step 64, where Re = -0.776 Im = 0.491
# running dynamics step65
# Finished step 65, where Re = -0.553 Im = 0.656
# running dynamics step66
# Finished step 66, where Re = -0.285 Im = 0.764
# running dynamics step67
# Finished step 67, where Re = 0.004 Im = 0.799
# running dynamics step68
# Finished step 68, where Re = 0.276 Im = 0.763
# running dynamics step69
# Finished step 69, where Re = 0.513 Im = 0.662
# running dynamics step70
# Finished step 70, where Re = 0.690 Im = 0.508
# running dynamics step71
# Finished step 71, where Re = 0.791 Im = 0.319
# running dynamics step72
# Finished step 72, where Re = 0.810 Im = 0.118
# running dynamics step73
# Finished step 73, where Re = 0.752 Im = -0.082
# running dynamics step74
# Finished step 74, where Re = 0.629 Im = -0.258
# running dynamics step75
# Finished step 75, where Re = 0.458 Im = -0.399
# running dynamics step76
# Finished step 76, where Re = 0.259 Im = -0.487
# running dynamics step77
# Finished step 77, where Re = 0.057 Im = -0.527
# running dynamics step78
# Finished step 78, where Re = -0.125 Im = -0.519
# running dynamics step79
# Finished step 79, where Re = -0.274 Im = -0.467
# running dynamics step80
# Finished step 80, where Re = -0.372 Im = -0.386
# running dynamics step81
# Finished step 81, where Re = -0.416 Im = -0.285
# running dynamics step82
# Finished step 82, where Re = -0.407 Im = -0.180
# running dynamics step83
# Finished step 83, where Re = -0.359 Im = -0.083
# running dynamics step84
# Finished step 84, where Re = -0.279 Im = -0.003
# running dynamics step85
# Finished step 85, where Re = -0.189 Im = 0.060
# running dynamics step86
# Finished step 86, where Re = -0.100 Im = 0.094
# running dynamics step87
# Finished step 87, where Re = -0.030 Im = 0.109
# running dynamics step88
# Finished step 88, where Re = 0.013 Im = 0.110
# running dynamics step89
# Finished step 89, where Re = 0.025 Im = 0.106
# running dynamics step90
# Finished step 90, where Re = 0.004 Im = 0.104
# running dynamics step91
# Finished step 91, where Re = -0.041 Im = 0.105
# running dynamics step92
# Finished step 92, where Re = -0.097 Im = 0.124
# running dynamics step93
# Finished step 93, where Re = -0.149 Im = 0.157
# running dynamics step94
# Finished step 94, where Re = -0.189 Im = 0.196
# running dynamics step95
# Finished step 95, where Re = -0.195 Im = 0.245
# running dynamics step96
# Finished step 96, where Re = -0.167 Im = 0.294
# running dynamics step97
# Finished step 97, where Re = -0.096 Im = 0.328
# running dynamics step98
# Finished step 98, where Re = 0.010 Im = 0.338
# running dynamics step99
# Finished step 99, where Re = 0.147 Im = 0.319
