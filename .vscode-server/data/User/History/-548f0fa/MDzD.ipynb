# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
a=np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
import qiskit
print(qiskit.__version__)
# Out:
# 2.3.0

# %%
import matplotlib.pyplot as plt
La=[]
Lb=[]

a = 5
b = 10

La.append(a)
Lb.append(b)

plt.plot(La, Lb)
plt.show()

# %%
import qiskitaer
