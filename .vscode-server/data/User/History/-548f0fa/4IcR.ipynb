# %%
print("hello world")
# Out:
# hello world

# %%
import numpy as np
a=np.array([1, 2, 3])
print(a)
# Out:
# [1 2 3]

# %%
import qiskit
print(qiskit.__version__)
# Out:
# 2.3.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
La = []
Lb = []

a = 5
b = 10

La.append(a)
Lb.append(b)

plt.plot(La, Lb, 'o-')
plt.xlabel('La')
plt.ylabel('Lb')
plt.title('Simple plot')
plt.grid(True)
plt.show()

# %%
from qiskit import QuantumCircuit, Aer, execute
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/mgpfs/home/nhandayani/.conda/envs/env-cn/lib/python3.10/site-packages/qiskit/__init__.py)
