# %% [markdown]
# ## **GROVER'S ALGORITHM**

# %% [markdown]
# Algoritma Grover adalah algoritma kuantum untuk mencari satu solusi dari N kemungkinan tak teurut dengan kompleKsitas $ O(\sqrt{N}) $.

# %%
from qiskit import QuantumCircuit, execute
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 from qiskit import QuantumCircuit, execute
#
# ImportError: cannot import name 'execute' from 'qiskit' (/mgpfs/home/nhandayani/.conda/envs/env-cn/lib/python3.10/site-packages/qiskit/__init__.py)
